# %% [markdown]
# Task 3 -4 Численно найти действительне корни системы нелинейных уравнений:
#
#    x^2-y^2+3xy^3-2x^2y^2+2x-3y-5=0
#    3y^3-2x^2+2x^3y-5x^2y^2+5=0

# %%
from matplotlib import pylab as plt
import numpy as np
# %matplotlib inline

# %%
t=np.linspace(-5,5,50)
x,y=np.meshgrid(t,t)
F= (x**2)-(y**2)+3*x*(y**3)-2*(x**2)*(y**2)+2*x-3*y-5
F1=3*(y**3)-2*(x**3)*y-5*(x**2)*(y**2)+5

plt.figure()
plt.contour(x, y, F, [0], linewidths=2,colors='b')
plt.contour(x, y, F1, [0], linewidths=2,colors='c')
plt.gcf().gca().axis('image')
plt.gcf().gca().grid(True)
plt.show()

# %%
from scipy.optimize import fsolve

def equations(p):
    x, y = p
    return ((x**2)-(y**2)+3*x*(y**3)-2*(x**2)*(y**2)+2*x-3*y-5, 3*(y**3)-2*(x**3)*y-5*(x**2)*(y**2)+5)

a = np.array([[-4.0,0.0],[0.5,2],[2,0.5]])
z = np.array([[0.0,0.0],[None,None],[None,None]])
k=0

for i in range(3):
    x1, y1 = fsolve(equations, (a[i,0],a[i,1]))
    z[k] = x1, y1
    k +=1
    
print (z)
# Out:
# [[-3.4302702988027622 -0.05936173640856687]
#  [1.052931121103871 1.7472413794946118]
#  [1.7479894137192267 0.3259005058103779]]
